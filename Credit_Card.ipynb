# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
url = 'https://storage.googleapis.com/download.tensorflow.org/data/creditcard.csv'

# %%
df = pd.read_csv(url)
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
# --- Count missing values ---
print("Missing Values Count:")
df.isnull().sum()
# Out:
# Missing Values Count:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
# --- Show top 3 correlations ---
print("\nTop 3 Negative Correlations with 'Class':")
top_correlations = df.corr()['Class'].sort_values(ascending=True).head(3)
top_correlations
# Out:
# Top 3 Negative Correlations with 'Class':
# V17   -0.326481
# V14   -0.302544
# V12   -0.260593
# Name: Class, dtype: float64

# %%
# --- Plot one histogram ---
plt.figure(figsize=(10, 6))
sns.histplot(df[df['Amount'] < 500]['Amount'], bins=50, kde=True)
plt.title('Distribution of Transaction Amounts (Under $500)')
plt.xlabel('Transaction Amount ($)')
plt.ylabel('Frequency')
plt.show()
